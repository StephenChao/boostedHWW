# %%
import uproot
import awkward as ak
import numpy as np
import math
import sklearn.metrics as m
import numba as nb
from coffea.nanoevents.methods import vector
from coffea.nanoevents import NanoEventsFactory, BaseSchema, NanoAODSchema
import os

import boost_histogram as bh
from matplotlib import pyplot as plt
import matplotlib as mpl
from cycler import cycler
import mplhep as hep
use_helvet = True  ## true: use helvetica for plots, make sure the system have the font installed
if use_helvet:
    CMShelvet = hep.style.CMS
    CMShelvet['font.sans-serif'] = ['Helvetica', 'Arial']
    plt.style.use(CMShelvet)
else:
    plt.style.use(hep.style.CMS)

import os, sys  

# os.environ['OPENBLAS_NUM_THREADS'] = '1'

class dotdict(dict):
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

#env:lpr

# %% [markdown]
# ### find tlb jet tagger distribution

# %%
deltaR = 0.8

d_PDGID = 1
b_PDGID = 5
g_PDGID = 21
TOP_PDGID = 6

ELE_PDGID = 11
vELE_PDGID = 12
MU_PDGID = 13
vMU_PDGID = 14
TAU_PDGID = 15
vTAU_PDGID = 16

Z_PDGID = 23
W_PDGID = 24
HIGGS_PDGID = 25

GEN_FLAGS = ["fromHardProcess", "isLastCopy"]

# %%
def pad_val(
arr: ak.Array,
target: int,
value: float,
axis: int = 0,
to_numpy: bool = True,
clip: bool = True,
):
    """
    pads awkward array up to ``target`` index along axis ``axis`` with value ``value``,
    optionally converts to numpy array
    """
    ret = ak.fill_none(ak.pad_none(arr, target, axis=axis, clip=clip), value, axis=axis)
    return ret.to_numpy() if to_numpy else ret

# %% [markdown]
# ### processing

# %%
from coffea import processor, hist
from functools import partial

class TblNodeAnalyzeProcessor(processor.ProcessorABC):
    def __init__(self):
        dataset = hist.Cat("dataset", "dataset")

        self._accumulator = processor.dict_accumulator({
            # defination of cutflow (nested dictionary of int) copied from the example
            'cutflow': processor.defaultdict_accumulator(
                partial(processor.defaultdict_accumulator, int)
            ),
        })

    @property
    def accumulator(self):
        return self._accumulator

    def process(self, events):
        out = self.accumulator.identity()
        dataset = events.metadata['dataset']
        out['cutflow'][dataset]['all'] += len(events)

        fname = f"coffea_output/{dataset}_ele/{events.metadata['filename'].split('/')[-1].replace('.root','')}_{int(events.metadata['entrystop'])}.root"
        
        #at least one AK8 jets
        events = events[ak.num(events.FatJet) >= 1]
        
        # ======
        #gen-matching selection
        tops = events.GenPart[
        (abs(events.GenPart.pdgId) == TOP_PDGID) * events.GenPart.hasFlags(GEN_FLAGS)
        ]
        
        tops_children = tops.distinctChildren
        tops_children = tops_children[tops_children.hasFlags(GEN_FLAGS)]
        ws = ak.flatten(tops_children[np.abs(tops_children.pdgId) == W_PDGID], axis=2)
        
        #only select semi-lep ttbar for simplicity
        lep_top_sel = ((np.all(np.abs(ws.children.pdgId[:,0]) > 5,axis = 1) & (np.all(np.abs(ws.children.pdgId[:,1]) <= 5,axis = 1))) | (np.all(np.abs(ws.children.pdgId[:,1]) > 5,axis = 1) & (np.all(np.abs(ws.children.pdgId[:,0]) <= 5,axis = 1))))
        lep_top_sel = ak.fill_none(lep_top_sel,False)
        events = events[lep_top_sel] #semi-lep ttbar events
        
        # print(events)
        
        #find the leptonic W
        lep_ws_sel = np.all(np.abs(ws[lep_top_sel].children.pdgId) > 5, axis=2)
        lep_ws = ak.flatten(ws[lep_top_sel][lep_ws_sel])
        
        #find lepton: only select electron
        lepton_sel = (np.abs(lep_ws.children.pdgId) == 11)
        lepton = lep_ws.children[lepton_sel]
        
        #find leptonic top
        lep_tops = tops[lep_top_sel][lep_ws_sel]
        lep_top_children = ak.flatten(lep_tops.children, axis=1)
        lep_bs = lep_top_children[np.abs(lep_top_children.pdgId) == 5]

        #get leading Fatjet
        num_jets = 1
        fatjets = events.FatJet
        deltaR = 0.8
        leading_fatjets = ak.pad_none(fatjets, num_jets, axis=1)[:, :num_jets]
        
        lep_jet_match = ak.flatten(
            pad_val(lepton.delta_r(leading_fatjets[:, 0]) < deltaR, target = 1, value = False, axis=1, to_numpy=False)
        )
        lep_b_jet_match = ak.flatten(
            pad_val(lep_bs.delta_r(leading_fatjets[:, 0]) < deltaR, target = 1, value = False, axis=1, to_numpy=False)
        )
        
        #select the events whose leading jet is actually tbl jet
        events = events[ak.fill_none(lep_jet_match * lep_b_jet_match,False)]
        
        # =====
        
        # lepton selection
        lep_sel = (ak.num(events.Electron) + ak.num(events.Muon) == 1) & (ak.num(events.Jet) >= 2) & (ak.num(events.FatJet) >= 1)
        events = events[lep_sel]

        # the lepton object
        lep = ak.concatenate([events.Electron, events.Muon], axis=1)[:, 0]
        lep_isel = ak.num(events.Electron) > 0

        # jet and MET selection
        jet_sel = (events.Jet.pt[:, 0] > 50) & (events.Jet.pt[:, 1] > ak.where(lep_isel, 40, 50))
        jet_btagsel = ak.num(events.Jet[events.Jet.btagDeepFlavB > 0.3040]) >= 1 # MP in 2017 deepjet, https://btv-wiki.docs.cern.ch/ScaleFactors/UL2017/#ak4-b-tagging

        met_sel = events.MET.pt > ak.where(lep_isel, 60, 70)

        # fatjet selection
        fatjet = events.FatJet[:, 0]
        fatjet_sel = (fatjet.pt > 400) & (fatjet.msoftdrop > 105) & (fatjet.msoftdrop < 210)

        # fatjet top-tagging discr. We use ParT (MD) to construct the t->bqq discr and manually cut at 1% mistag WP
        num = 'inclParTMDV1_probTopbWqq0c + inclParTMDV1_probTopbWqq1c + inclParTMDV1_probTopbWq0c + inclParTMDV1_probTopbWq1c'
        num_bl = 'inclParTMDV1_probTopbWev + inclParTMDV1_probTopbWmv'
        discr = f'({num_bl}) / ({num_bl} + inclParTMDV1_probQCDbb + inclParTMDV1_probQCDcc + inclParTMDV1_probQCDb + inclParTMDV1_probQCDc + inclParTMDV1_probQCDothers)'
        fatjet_toptagsel = ak.numexpr.evaluate(discr, fatjet) > 0.27 # 1% mistag rate on QCD

        # selection based on all objects
        # sel = jet_sel & jet_btagsel & met_sel & fatjet_sel & fatjet_toptagsel
        sel = jet_sel & jet_btagsel & met_sel # let's remove the fatjet sel for now
        events = events[sel]

        # ==== Now we finished all selections ====

        # define objects
        fj1 = events.FatJet[:, 0]
        fj2 = events.mask[ak.num(events.FatJet) >= 2].FatJet[:, 1] # use mask since a second fj may not exist

        jets = events.Jet
        lep = ak.concatenate([events.Electron, events.Muon], axis=1)[:, 0]
        lep_isel = ak.num(events.Electron) > 0

        # t->bqq discr
        num = 'inclParTMDV1_probTopbWqq0c + inclParTMDV1_probTopbWqq1c + inclParTMDV1_probTopbWq0c + inclParTMDV1_probTopbWq1c'
        fj1_ParTV1_discr_bqqvsQCD = ak.numexpr.evaluate(f'({num}) / ({num} + inclParTMDV1_probQCDbb + inclParTMDV1_probQCDcc + inclParTMDV1_probQCDb + inclParTMDV1_probQCDc + inclParTMDV1_probQCDothers)', fj1)
        
        # t->bl discr
        num_bl = 'inclParTMDV1_probTopbWev + inclParTMDV1_probTopbWmv'
        num_bel = 'inclParTMDV1_probTopbWev'
        num_bmul = 'inclParTMDV1_probTopbWmv'
        num_bell = 'inclParTMDV1_probTopbWev + inclParTMDV1_probTopbWmv + inclParTMDV1_probTopbWtauev + inclParTMDV1_probTopbWtaumv'
        fj1_ParTV1_discr_blvsQCD = ak.numexpr.evaluate(f'({num_bl}) / ({num_bl} + inclParTMDV1_probQCDbb + inclParTMDV1_probQCDcc + inclParTMDV1_probQCDb + inclParTMDV1_probQCDc + inclParTMDV1_probQCDothers)', fj1)
        
        # bevsQCD
        fj1_ParTV1_discr_bevsQCD = ak.numexpr.evaluate(f'({num_bel}) / ({num_bel} + inclParTMDV1_probQCDbb + inclParTMDV1_probQCDcc + inclParTMDV1_probQCDb + inclParTMDV1_probQCDc + inclParTMDV1_probQCDothers)', fj1)
        # bmuvsQCD
        fj1_ParTV1_discr_bmuvsQCD = ak.numexpr.evaluate(f'({num_bmul}) / ({num_bmul} + inclParTMDV1_probQCDbb + inclParTMDV1_probQCDcc + inclParTMDV1_probQCDb + inclParTMDV1_probQCDc + inclParTMDV1_probQCDothers)', fj1)
        
        fj2_ParTV1_discr_blvsQCD = ak.numexpr.evaluate(f'({num_bl}) / ({num_bl} + inclParTMDV1_probQCDbb + inclParTMDV1_probQCDcc + inclParTMDV1_probQCDb + inclParTMDV1_probQCDc + inclParTMDV1_probQCDothers)', fj2)
        fj2_ParTV1_discr_bellvsQCD = ak.numexpr.evaluate(f'({num_bell}) / ({num_bell} + inclParTMDV1_probQCDbb + inclParTMDV1_probQCDcc + inclParTMDV1_probQCDb + inclParTMDV1_probQCDc + inclParTMDV1_probQCDothers)', fj2)

        # the 2D reconstruction workflow

        pair = ak.cartesian([lep, jets[jets.pt > 15]]) # all lep-jet pair with jet pt > 15
        dr_pair = pair['1'].delta_r(pair['0'])
        mindr_ind = ak.singletons(ak.argmin(dr_pair, axis=1))

        jet_closest = pair['1'][mindr_ind][:, 0]
        mindr = dr_pair[mindr_ind][:, 0]

        ptrel = lep.pt * np.abs(np.sin(lep.phi - jet_closest.phi)) # lep pt *perpendicular* to jet axis

        # construct output variables
        print("start store output")
        output = {}
        output['fj1_pt'] = fj1.pt
        output['fj1_eta'] = fj1.eta
        output['fj1_phi'] = fj1.phi
        output['fj1_sdmass'] = fj1.msoftdrop
        output['fj2_pt'] = ak.fill_none(fj2.pt, 0)
        output['fj2_eta'] = ak.fill_none(fj2.eta, 0)
        output['fj2_phi'] = ak.fill_none(fj2.phi, 0)
        output['fj2_sdmass'] = ak.fill_none(fj2.msoftdrop, 0)

        output['fj1_ParTV1_discr_bqqvsQCD'] = ak.fill_none(fj1_ParTV1_discr_bqqvsQCD, 0)
        output['fj1_ParTV1_discr_blvsQCD'] = ak.fill_none(fj1_ParTV1_discr_blvsQCD, 0)
        
        # bevsQCD
        output['fj1_ParTV1_discr_bevsQCD'] = ak.fill_none(fj1_ParTV1_discr_bevsQCD, 0)
        # bmuvsQCD
        output['fj1_ParTV1_discr_bmuvsQCD'] = ak.fill_none(fj1_ParTV1_discr_bmuvsQCD, 0)
        
        output['fj2_ParTV1_discr_blvsQCD'] = ak.fill_none(fj2_ParTV1_discr_blvsQCD, 0)
        output['fj2_ParTV1_discr_bellvsQCD'] = ak.fill_none(fj2_ParTV1_discr_bellvsQCD, 0)

        output['dr_fj12'] = ak.fill_none(fj1.delta_r(fj2), -1)

        output['lep_pt'] = lep.pt
        output['lep_eta'] = lep.eta
        output['lep_phi'] = lep.phi
        output['lep_isel'] = lep_isel
        output['lep_mindr_jet'] = mindr
        output['lep_ptrel_jet'] = ptrel

        output['deta_jet12'] = jets[:, 0].eta - jets[:, 1].eta

        # store root
        print(fname)
        os.makedirs(os.path.dirname(fname), exist_ok=True)
        with uproot.recreate(fname) as fout:
            output_root = {}
            for bname in output.keys():
                if not output[bname].fields:
                    output_root[bname] = ak.packed(ak.without_parameters(output[bname]))
                else:
                    b_nest = {}
                    for n in output[bname].fields:
                        b_nest[n] = ak.packed(ak.without_parameters(output[bname][n]))
                    output_root[bname] = ak.zip(b_nest)
            fout["tree"] = output_root

        out['cutflow'][dataset]['passed'] += len(events)
        return out
    
    def postprocess(self, accumulator):
        return accumulator
# Out:
# /home/pku/zhaoyz/anaconda3/envs/lpr/lib/python3.9/site-packages/coffea/util.py:154: FutureWarning: In coffea version v2023.3.0 (target date: 31 Mar 2023), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
import glob
fileset = {
    'ttbar': glob.glob('/data/bond/fudawei/public/customizedNanoAOD/output/mc/2017/TTJets/TTJets/*.root'),
    # 'qcd': glob.glob('/data/bond/fudawei/public/customizedNanoAOD/output/mc/2017/QCD/QCD_HT1000to1500/*.root'),
}

# %%
result = processor.run_uproot_job(
    fileset=fileset,
    treename="Events",
    processor_instance=TblNodeAnalyzeProcessor(),
    executor=processor.futures_executor,
    executor_args={"schema": NanoAODSchema, "workers": 60},
)
# Out:
# /home/pku/zhaoyz/anaconda3/envs/lpr/lib/python3.9/site-packages/rich/live.py:231: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# start store output
# coffea_output/ttbar_ele/merged_124_99889.root
# start store output
# coffea_output/ttbar_ele/merged_124_399556.root
# start store output
# coffea_output/ttbar_ele/merged_124_299667.root
# start store output
# coffea_output/ttbar_ele/merged_124_199778.root
# start store output
# coffea_output/ttbar_ele/merged_124_499445.root
# start store output
# coffea_output/ttbar_ele/merged_197_699083.root
# start store output
# coffea_output/ttbar_ele/merged_197_499345.root
# start store output
# coffea_output/ttbar_ele/merged_197_599214.root
# start store output
# coffea_output/ttbar_ele/merged_197_299607.root
# start store output
# coffea_output/ttbar_ele/merged_197_898821.root
# start store output
# coffea_output/ttbar_ele/merged_197_399476.root
# start store output
# coffea_output/ttbar_ele/merged_197_1098558.root
# start store output
# coffea_output/ttbar_ele/merged_197_798952.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_197_199738.root
# coffea_output/ttbar_ele/merged_197_99869.root
# start store output
# coffea_output/ttbar_ele/merged_197_998690.root
# start store output
# coffea_output/ttbar_ele/merged_124_599334.root
# start store output
# coffea_output/ttbar_ele/merged_124_899001.root
# start store output
# coffea_output/ttbar_ele/merged_124_998890.root
# start store output
# coffea_output/ttbar_ele/merged_124_799112.root
# start store output
# coffea_output/ttbar_ele/merged_124_699223.root
# start store output
# coffea_output/ttbar_ele/merged_124_1098773.root
# start store output
# coffea_output/ttbar_ele/merged_105_291144.root
# start store output
# coffea_output/ttbar_ele/merged_105_582288.root
# start store output
# coffea_output/ttbar_ele/merged_105_970480.root
# start store output
# coffea_output/ttbar_ele/merged_133_898164.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_105_97048.root
# coffea_output/ttbar_ele/merged_105_776384.root
# start store output
# coffea_output/ttbar_ele/merged_43_97251.root
# start store output
# coffea_output/ttbar_ele/merged_105_679336.root
# start store output
# coffea_output/ttbar_ele/merged_105_388192.root
# start store output
# coffea_output/ttbar_ele/merged_105_485240.root
# start store output
# coffea_output/ttbar_ele/merged_105_1067523.root
# start store output
# coffea_output/ttbar_ele/merged_105_194096.root
# start store output
# coffea_output/ttbar_ele/merged_105_873432.root
# start store output
# coffea_output/ttbar_ele/merged_133_399184.root
# start store output
# coffea_output/ttbar_ele/merged_34_1096987.root
# start store output
# coffea_output/ttbar_ele/merged_34_398908.root
# start store output
# coffea_output/ttbar_ele/merged_43_778008.root
# start store output
# coffea_output/ttbar_ele/merged_133_997960.root
# start store output
# coffea_output/ttbar_ele/merged_133_299388.root
# start store output
# coffea_output/ttbar_ele/merged_133_598776.root
# start store output
# coffea_output/ttbar_ele/merged_133_1097756.root
# start store output
# coffea_output/ttbar_ele/merged_133_698572.root
# start store output
# coffea_output/ttbar_ele/merged_133_798368.root
# start store output
# coffea_output/ttbar_ele/merged_133_99796.root
# start store output
# coffea_output/ttbar_ele/merged_34_997270.root
# start store output
# coffea_output/ttbar_ele/merged_133_498980.root
# start store output
# coffea_output/ttbar_ele/merged_133_199592.root
# start store output
# coffea_output/ttbar_ele/merged_43_194502.root
# start store output
# coffea_output/ttbar_ele/merged_34_99727.root
# start store output
# coffea_output/ttbar_ele/merged_34_199454.root
# start store output
# coffea_output/ttbar_ele/merged_43_583506.root
# start store output
# coffea_output/ttbar_ele/merged_34_299181.root
# start store output
# coffea_output/ttbar_ele/merged_34_897543.root
# start store output
# coffea_output/ttbar_ele/merged_34_598362.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_43_1069751.root
# coffea_output/ttbar_ele/merged_43_389004.root
# start store output
# coffea_output/ttbar_ele/merged_43_972510.root
# start store output
# coffea_output/ttbar_ele/merged_34_498635.root
# start store output
# coffea_output/ttbar_ele/merged_43_875259.root
# start store output
# coffea_output/ttbar_ele/merged_43_680757.root
# start store output
# coffea_output/ttbar_ele/merged_34_797816.root
# start store output
# coffea_output/ttbar_ele/merged_43_486255.root
# start store output
# coffea_output/ttbar_ele/merged_43_291753.root
# start store output
# coffea_output/ttbar_ele/merged_34_698089.root
# start store output
# coffea_output/ttbar_ele/merged_153_300021.root
# start store output
# coffea_output/ttbar_ele/merged_153_200014.root
# start store output
# coffea_output/ttbar_ele/merged_83_191788.root
# start store output
# coffea_output/ttbar_ele/merged_153_100007.root
# start store output
# coffea_output/ttbar_ele/merged_153_400028.root
# start store output
# coffea_output/ttbar_ele/merged_153_500035.root
# start store output
# coffea_output/ttbar_ele/merged_83_95894.root
# start store output
# coffea_output/ttbar_ele/merged_83_575364.root
# start store output
# coffea_output/ttbar_ele/merged_83_1054828.root
# start store output
# coffea_output/ttbar_ele/merged_83_767152.root
# start store output
# coffea_output/ttbar_ele/merged_83_863046.root
# start store output
# coffea_output/ttbar_ele/merged_83_958940.root
# start store output
# coffea_output/ttbar_ele/merged_83_671258.root
# start store output
# coffea_output/ttbar_ele/merged_83_287682.root
# start store output
# coffea_output/ttbar_ele/merged_83_383576.root
# start store output
# coffea_output/ttbar_ele/merged_83_479470.root
# start store output
# coffea_output/ttbar_ele/merged_54_499680.root
# start store output
# coffea_output/ttbar_ele/merged_54_999360.root
# start store output
# coffea_output/ttbar_ele/merged_54_199872.root
# start store output
# coffea_output/ttbar_ele/merged_54_399744.root
# start store output
# coffea_output/ttbar_ele/merged_54_99936.root
# start store output
# coffea_output/ttbar_ele/merged_54_899424.root
# start store output
# coffea_output/ttbar_ele/merged_54_299808.root
# start store output
# coffea_output/ttbar_ele/merged_54_799488.root
# start store output
# coffea_output/ttbar_ele/merged_54_599616.root
# start store output
# coffea_output/ttbar_ele/merged_54_699552.root
# start store output
# coffea_output/ttbar_ele/merged_54_1099292.root
# start store output
# coffea_output/ttbar_ele/merged_153_900063.root
# start store output
# coffea_output/ttbar_ele/merged_153_600042.root
# start store output
# coffea_output/ttbar_ele/merged_153_1100075.root
# start store output
# coffea_output/ttbar_ele/merged_153_1000070.root
# start store output
# coffea_output/ttbar_ele/merged_153_700049.root
# start store output
# coffea_output/ttbar_ele/merged_153_800056.root
# start store output
# coffea_output/ttbar_ele/merged_181_299151.root
# start store output
# coffea_output/ttbar_ele/merged_103_1098881.root
# start store output
# coffea_output/ttbar_ele/merged_103_899091.root
# start store output
# coffea_output/ttbar_ele/merged_181_698019.root
# start store output
# coffea_output/ttbar_ele/merged_181_498585.root
# start store output
# coffea_output/ttbar_ele/merged_181_997170.root
# start store output
# coffea_output/ttbar_ele/merged_103_199798.root
# start store output
# coffea_output/ttbar_ele/merged_181_1096880.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_181_199434.root
# coffea_output/ttbar_ele/merged_181_99717.root
# start store output
# coffea_output/ttbar_ele/merged_181_797736.root
# start store output
# coffea_output/ttbar_ele/merged_181_598302.root
# start store output
# coffea_output/ttbar_ele/merged_181_398868.root
# start store output
# coffea_output/ttbar_ele/merged_103_799192.root
# start store output
# coffea_output/ttbar_ele/merged_181_897453.root
# start store output
# coffea_output/ttbar_ele/merged_103_998990.root
# start store output
# coffea_output/ttbar_ele/merged_103_599394.root
# start store output
# coffea_output/ttbar_ele/merged_103_399596.root
# start store output
# coffea_output/ttbar_ele/merged_68_999030.root
# start store output
# coffea_output/ttbar_ele/merged_103_499495.root
# start store output
# coffea_output/ttbar_ele/merged_103_699293.root
# start store output
# coffea_output/ttbar_ele/merged_103_299697.root
# start store output
# coffea_output/ttbar_ele/merged_68_199806.root
# start store output
# coffea_output/ttbar_ele/merged_103_99899.root
# start store output
# coffea_output/ttbar_ele/merged_68_799224.root
# start store output
# coffea_output/ttbar_ele/merged_68_899127.root
# start store output
# coffea_output/ttbar_ele/merged_68_399612.root
# start store output
# coffea_output/ttbar_ele/merged_68_299709.root
# start store output
# coffea_output/ttbar_ele/merged_68_1098928.root
# start store output
# coffea_output/ttbar_ele/merged_68_699321.root
# start store output
# coffea_output/ttbar_ele/merged_68_99903.root
# start store output
# coffea_output/ttbar_ele/merged_68_499515.root
# start store output
# coffea_output/ttbar_ele/merged_68_599418.root
# start store output
# coffea_output/ttbar_ele/merged_202_999420.root
# start store output
# coffea_output/ttbar_ele/merged_202_699594.root
# start store output
# coffea_output/ttbar_ele/merged_202_99942.root
# start store output
# coffea_output/ttbar_ele/merged_202_199884.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_202_599652.root
# coffea_output/ttbar_ele/merged_202_899478.root
# start store output
# coffea_output/ttbar_ele/merged_202_299826.root
# start store output
# coffea_output/ttbar_ele/merged_202_399768.root
# start store output
# coffea_output/ttbar_ele/merged_202_799536.root
# start store output
# coffea_output/ttbar_ele/merged_202_1099358.root
# start store output
# coffea_output/ttbar_ele/merged_202_499710.root
# start store output
# coffea_output/ttbar_ele/merged_59_97625.root
# start store output
# coffea_output/ttbar_ele/merged_59_292875.root
# start store output
# coffea_output/ttbar_ele/merged_59_390500.root
# start store output
# coffea_output/ttbar_ele/merged_59_488125.root
# start store output
# coffea_output/ttbar_ele/merged_59_195250.root
# start store output
# coffea_output/ttbar_ele/merged_4_1053319.root
# start store output
# coffea_output/ttbar_ele/merged_4_383028.root
# start store output
# coffea_output/ttbar_ele/merged_4_670299.root
# start store output
# coffea_output/ttbar_ele/merged_4_287271.root
# start store output
# coffea_output/ttbar_ele/merged_4_478785.root
# start store output
# coffea_output/ttbar_ele/merged_4_957570.root
# start store output
# coffea_output/ttbar_ele/merged_4_191514.root
# start store output
# coffea_output/ttbar_ele/merged_4_861813.root
# start store output
# coffea_output/ttbar_ele/merged_4_574542.root
# start store output
# coffea_output/ttbar_ele/merged_4_95757.root
# start store output
# coffea_output/ttbar_ele/merged_4_766056.root
# start store output
# coffea_output/ttbar_ele/merged_26_199846.root
# start store output
# coffea_output/ttbar_ele/merged_26_99923.root
# start store output
# coffea_output/ttbar_ele/merged_26_899307.root
# start store output
# coffea_output/ttbar_ele/merged_26_599538.root
# start store output
# coffea_output/ttbar_ele/merged_26_1099152.root
# start store output
# coffea_output/ttbar_ele/merged_26_399692.root
# start store output
# coffea_output/ttbar_ele/merged_26_999230.root
# start store output
# coffea_output/ttbar_ele/merged_26_799384.root
# start store output
# coffea_output/ttbar_ele/merged_26_499615.root
# start store output
# coffea_output/ttbar_ele/merged_26_299769.root
# start store output
# coffea_output/ttbar_ele/merged_26_699461.root
# start store output
# coffea_output/ttbar_ele/merged_191_799792.root
# start store output
# coffea_output/ttbar_ele/merged_191_299922.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_191_899766.root
# coffea_output/ttbar_ele/merged_191_499870.root
# start store output
# coffea_output/ttbar_ele/merged_191_99974.root
# start store output
# coffea_output/ttbar_ele/merged_191_199948.root
# start store output
# coffea_output/ttbar_ele/merged_191_699818.root
# start store output
# coffea_output/ttbar_ele/merged_191_999740.root
# start store output
# coffea_output/ttbar_ele/merged_141_499300.root
# start store output
# coffea_output/ttbar_ele/merged_191_1099714.root
# start store output
# coffea_output/ttbar_ele/merged_191_399896.root
# start store output
# coffea_output/ttbar_ele/merged_191_599844.root
# start store output
# coffea_output/ttbar_ele/merged_141_998600.root
# start store output
# coffea_output/ttbar_ele/merged_141_1098451.root
# start store output
# coffea_output/ttbar_ele/merged_141_99860.root
# start store output
# coffea_output/ttbar_ele/merged_141_798880.root
# start store output
# coffea_output/ttbar_ele/merged_141_299580.root
# start store output
# coffea_output/ttbar_ele/merged_141_399440.root
# start store output
# coffea_output/ttbar_ele/merged_141_199720.root
# start store output
# coffea_output/ttbar_ele/merged_141_699020.root
# start store output
# coffea_output/ttbar_ele/merged_141_898740.root
# start store output
# coffea_output/ttbar_ele/merged_141_599160.root
# start store output
# coffea_output/ttbar_ele/merged_59_1073875.root
# start store output
# coffea_output/ttbar_ele/merged_59_585750.root
# start store output
# coffea_output/ttbar_ele/merged_59_878625.root
# start store output
# coffea_output/ttbar_ele/merged_59_683375.root
# start store output
# coffea_output/ttbar_ele/merged_59_781000.root
# start store output
# coffea_output/ttbar_ele/merged_59_976250.root
# start store output
# coffea_output/ttbar_ele/merged_216_598056.root
# start store output
# coffea_output/ttbar_ele/merged_216_897084.root
# start store output
# coffea_output/ttbar_ele/merged_216_498380.root
# start store output
# coffea_output/ttbar_ele/merged_216_299028.root
# start store output
# coffea_output/ttbar_ele/merged_216_99676.root
# start store output
# coffea_output/ttbar_ele/merged_216_697732.root
# start store output
# coffea_output/ttbar_ele/merged_216_797408.root
# start store output
# coffea_output/ttbar_ele/merged_216_398704.root
# start store output
# coffea_output/ttbar_ele/merged_216_996760.root
# start store output
# coffea_output/ttbar_ele/merged_216_199352.root
# start store output
# coffea_output/ttbar_ele/merged_216_1096431.root
# start store output
# coffea_output/ttbar_ele/merged_138_898353.root
# start store output
# coffea_output/ttbar_ele/merged_138_998170.root
# start store output
# coffea_output/ttbar_ele/merged_138_299451.root
# start store output
# coffea_output/ttbar_ele/merged_138_199634.root
# start store output
# coffea_output/ttbar_ele/merged_138_399268.root
# start store output
# coffea_output/ttbar_ele/merged_138_598902.root
# start store output
# coffea_output/ttbar_ele/merged_138_99817.root
# start store output
# coffea_output/ttbar_ele/merged_138_698719.root
# start store output
# coffea_output/ttbar_ele/merged_138_1097983.root
# start store output
# coffea_output/ttbar_ele/merged_138_798536.root
# start store output
# coffea_output/ttbar_ele/merged_138_499085.root
# start store output
# coffea_output/ttbar_ele/merged_111_699573.root
# start store output
# coffea_output/ttbar_ele/merged_111_299817.root
# start store output
# coffea_output/ttbar_ele/merged_111_899451.root
# start store output
# coffea_output/ttbar_ele/merged_111_799512.root
# start store output
# coffea_output/ttbar_ele/merged_111_499695.root
# start store output
# coffea_output/ttbar_ele/merged_111_999390.root
# start store output
# coffea_output/ttbar_ele/merged_111_399756.root
# start store output
# coffea_output/ttbar_ele/merged_111_199878.root
# start store output
# coffea_output/ttbar_ele/merged_111_1099325.root
# start store output
# coffea_output/ttbar_ele/merged_111_599634.root
# start store output
# coffea_output/ttbar_ele/merged_111_99939.root
# start store output
# coffea_output/ttbar_ele/merged_42_799368.root
# start store output
# coffea_output/ttbar_ele/merged_42_699447.root
# start store output
# coffea_output/ttbar_ele/merged_42_399684.root
# start store output
# coffea_output/ttbar_ele/merged_42_1099124.root
# start store output
# coffea_output/ttbar_ele/merged_42_899289.root
# start store output
# coffea_output/ttbar_ele/merged_42_99921.root
# start store output
# coffea_output/ttbar_ele/merged_42_999210.root
# start store output
# coffea_output/ttbar_ele/merged_42_599526.root
# start store output
# coffea_output/ttbar_ele/merged_42_199842.root
# start store output
# coffea_output/ttbar_ele/merged_42_499605.root
# start store output
# coffea_output/ttbar_ele/merged_42_299763.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_10_199574.root
# coffea_output/ttbar_ele/merged_10_1097652.root
# start store output
# coffea_output/ttbar_ele/merged_10_299361.root
# start store output
# coffea_output/ttbar_ele/merged_10_698509.root
# start store output
# coffea_output/ttbar_ele/merged_10_498935.root
# start store output
# coffea_output/ttbar_ele/merged_10_798296.root
# start store output
# coffea_output/ttbar_ele/merged_10_997870.root
# start store output
# coffea_output/ttbar_ele/merged_10_598722.root
# start store output
# coffea_output/ttbar_ele/merged_10_898083.root
# start store output
# coffea_output/ttbar_ele/merged_10_399148.root
# start store output
# coffea_output/ttbar_ele/merged_10_99787.root
# start store output
# coffea_output/ttbar_ele/merged_160_798744.root
# start store output
# coffea_output/ttbar_ele/merged_160_499215.root
# start store output
# coffea_output/ttbar_ele/merged_160_99843.root
# start store output
# coffea_output/ttbar_ele/merged_160_1098263.root
# start store output
# coffea_output/ttbar_ele/merged_3_1000800.root
# start store output
# coffea_output/ttbar_ele/merged_160_898587.root
# start store output
# coffea_output/ttbar_ele/merged_3_900720.root
# start store output
# coffea_output/ttbar_ele/merged_160_698901.root
# start store output
# coffea_output/ttbar_ele/merged_160_299529.root
# start store output
# coffea_output/ttbar_ele/merged_160_998430.root
# start store output
# coffea_output/ttbar_ele/merged_3_300240.root
# start store output
# coffea_output/ttbar_ele/merged_3_500400.root
# start store output
# coffea_output/ttbar_ele/merged_160_199686.root
# start store output
# coffea_output/ttbar_ele/merged_160_399372.root
# start store output
# coffea_output/ttbar_ele/merged_3_600480.root
# start store output
# coffea_output/ttbar_ele/merged_160_599058.root
# start store output
# coffea_output/ttbar_ele/merged_3_400320.root
# start store output
# coffea_output/ttbar_ele/merged_3_800640.root
# start store output
# coffea_output/ttbar_ele/merged_3_1100878.root
# start store output
# coffea_output/ttbar_ele/merged_3_700560.root
# start store output
# coffea_output/ttbar_ele/merged_3_100080.root
# start store output
# coffea_output/ttbar_ele/merged_3_200160.root
# start store output
# coffea_output/ttbar_ele/merged_6_686014.root
# start store output
# coffea_output/ttbar_ele/merged_6_196004.root
# start store output
# coffea_output/ttbar_ele/merged_6_1078016.root
# start store output
# coffea_output/ttbar_ele/merged_6_294006.root
# start store output
# coffea_output/ttbar_ele/merged_6_392008.root
# start store output
# coffea_output/ttbar_ele/merged_6_588012.root
# start store output
# coffea_output/ttbar_ele/merged_6_784016.root
# start store output
# coffea_output/ttbar_ele/merged_6_98002.root
# start store output
# coffea_output/ttbar_ele/merged_6_882018.root
# start store output
# coffea_output/ttbar_ele/merged_6_980020.root
# start store output
# coffea_output/ttbar_ele/merged_6_490010.root
# start store output
# coffea_output/ttbar_ele/merged_18_299604.root
# start store output
# coffea_output/ttbar_ele/merged_18_499340.root
# start store output
# coffea_output/ttbar_ele/merged_18_998680.root
# start store output
# coffea_output/ttbar_ele/merged_18_399472.root
# start store output
# coffea_output/ttbar_ele/merged_18_199736.root
# start store output
# coffea_output/ttbar_ele/merged_18_99868.root
# start store output
# coffea_output/ttbar_ele/merged_18_798944.root
# start store output
# coffea_output/ttbar_ele/merged_18_1098547.root
# start store output
# coffea_output/ttbar_ele/merged_18_898812.root
# start store output
# coffea_output/ttbar_ele/merged_18_699076.root
# start store output
# coffea_output/ttbar_ele/merged_18_599208.root
# start store output
# coffea_output/ttbar_ele/merged_44_387032.root
# start store output
# coffea_output/ttbar_ele/merged_44_483790.root
# start store output
# coffea_output/ttbar_ele/merged_44_96758.root
# start store output
# coffea_output/ttbar_ele/merged_152_99758.root
# start store output
# coffea_output/ttbar_ele/merged_152_399032.root
# start store output
# coffea_output/ttbar_ele/merged_152_199516.root
# start store output
# coffea_output/ttbar_ele/merged_152_897822.root
# start store output
# coffea_output/ttbar_ele/merged_152_997580.root
# start store output
# coffea_output/ttbar_ele/merged_152_498790.root
# start store output
# coffea_output/ttbar_ele/merged_152_598548.root
# start store output
# coffea_output/ttbar_ele/merged_152_698306.root
# start store output
# coffea_output/ttbar_ele/merged_152_1097333.root
# start store output
# coffea_output/ttbar_ele/merged_152_798064.root
# start store output
# coffea_output/ttbar_ele/merged_152_299274.root
# start store output
# coffea_output/ttbar_ele/merged_63_399504.root
# start store output
# coffea_output/ttbar_ele/merged_63_998760.root
# start store output
# coffea_output/ttbar_ele/merged_63_898884.root
# start store output
# coffea_output/ttbar_ele/merged_108_191972.root
# start store output
# coffea_output/ttbar_ele/merged_108_671902.root
# start store output
# coffea_output/ttbar_ele/merged_108_863874.root
# start store output
# coffea_output/ttbar_ele/merged_63_699132.root
# start store output
# coffea_output/ttbar_ele/merged_108_1055846.root
# start store output
# coffea_output/ttbar_ele/merged_63_99876.root
# start store output
# coffea_output/ttbar_ele/merged_63_499380.root
# start store output
# coffea_output/ttbar_ele/merged_108_383944.root
# start store output
# coffea_output/ttbar_ele/merged_108_575916.root
# start store output
# coffea_output/ttbar_ele/merged_108_287958.root
# start store output
# coffea_output/ttbar_ele/merged_108_95986.root
# start store output
# coffea_output/ttbar_ele/merged_63_599256.root
# start store output
# coffea_output/ttbar_ele/merged_63_799008.root
# start store output
# coffea_output/ttbar_ele/merged_108_479930.root
# start store output
# coffea_output/ttbar_ele/merged_108_959860.root
# start store output
# coffea_output/ttbar_ele/merged_63_1098631.root
# start store output
# coffea_output/ttbar_ele/merged_63_199752.root
# start store output
# coffea_output/ttbar_ele/merged_108_767888.root
# start store output
# coffea_output/ttbar_ele/merged_130_999310.root
# start store output
# start store outputcoffea_output/ttbar_ele/merged_63_299628.root
#
# coffea_output/ttbar_ele/merged_130_499655.root
# start store output
# coffea_output/ttbar_ele/merged_130_1099233.root
# start store output
# coffea_output/ttbar_ele/merged_129_974810.root
# start store output
# coffea_output/ttbar_ele/merged_130_699517.root
# start store output
# coffea_output/ttbar_ele/merged_130_299793.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_130_599586.rootcoffea_output/ttbar_ele/merged_130_899379.root
#
# start store output
# start store output
# coffea_output/ttbar_ele/merged_130_99931.root
# coffea_output/ttbar_ele/merged_130_199862.root
# start store output
# coffea_output/ttbar_ele/merged_130_399724.root
# start store output
# coffea_output/ttbar_ele/merged_130_799448.root
# start store output
# coffea_output/ttbar_ele/merged_129_682367.root
# start store output
# coffea_output/ttbar_ele/merged_129_292443.root
# start store output
# coffea_output/ttbar_ele/merged_129_1072286.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_129_877329.root
# coffea_output/ttbar_ele/merged_129_779848.root
# start store output
# coffea_output/ttbar_ele/merged_129_389924.root
# start store output
# coffea_output/ttbar_ele/merged_129_584886.root
# start store output
# coffea_output/ttbar_ele/merged_44_193516.root
# start store output
# coffea_output/ttbar_ele/merged_129_194962.root
# start store output
# coffea_output/ttbar_ele/merged_129_97481.root
# start store output
# coffea_output/ttbar_ele/merged_129_487405.root
# start store output
# coffea_output/ttbar_ele/merged_44_290274.root
# start store output
# coffea_output/ttbar_ele/merged_44_1064336.root
# start store output
# coffea_output/ttbar_ele/merged_44_580548.root
# start store output
# coffea_output/ttbar_ele/merged_44_774064.root
# start store output
# coffea_output/ttbar_ele/merged_44_870822.root
# start store output
# coffea_output/ttbar_ele/merged_44_967580.root
# start store output
# coffea_output/ttbar_ele/merged_44_677306.root
# start store output
# coffea_output/ttbar_ele/merged_190_99755.root
# start store output
# coffea_output/ttbar_ele/merged_190_498775.root
# start store output
# coffea_output/ttbar_ele/merged_190_299265.root
# start store output
# coffea_output/ttbar_ele/merged_190_199510.root
# start store output
# coffea_output/ttbar_ele/merged_89_99849.root
# start store output
# coffea_output/ttbar_ele/merged_89_998490.root
# start store output
# coffea_output/ttbar_ele/merged_89_399396.root
# start store output
# coffea_output/ttbar_ele/merged_89_898641.root
# start store output
# coffea_output/ttbar_ele/merged_89_1098339.root
# start store output
# coffea_output/ttbar_ele/merged_89_698943.root
# start store output
# coffea_output/ttbar_ele/merged_89_499245.root
# start store output
# coffea_output/ttbar_ele/merged_89_798792.root
# start store output
# coffea_output/ttbar_ele/merged_89_299547.root
# start store output
# coffea_output/ttbar_ele/merged_89_599094.root
# start store output
# coffea_output/ttbar_ele/merged_89_199698.root
# start store output
# coffea_output/ttbar_ele/merged_144_196512.root
# start store output
# coffea_output/ttbar_ele/merged_39_100957.root
# start store output
# coffea_output/ttbar_ele/merged_196_997490.root
# start store output
# coffea_output/ttbar_ele/merged_190_399020.root
# start store output
# coffea_output/ttbar_ele/merged_196_199498.root
# start store output
# coffea_output/ttbar_ele/merged_144_884304.root
# start store output
# coffea_output/ttbar_ele/merged_39_1110526.root
# start store output
# coffea_output/ttbar_ele/merged_196_797992.root
# start store output
# coffea_output/ttbar_ele/merged_172_291075.root
# start store output
# coffea_output/ttbar_ele/merged_196_99749.root
# start store output
# coffea_output/ttbar_ele/merged_172_679175.root
# start store output
# coffea_output/ttbar_ele/merged_196_498745.root
# start store outputstart store output
#
# coffea_output/ttbar_ele/merged_172_388100.root
# coffea_output/ttbar_ele/merged_172_194050.root
# start store output
# coffea_output/ttbar_ele/merged_172_1067265.root
# start store output
# coffea_output/ttbar_ele/merged_196_698243.root
# start store output
# coffea_output/ttbar_ele/merged_172_873225.root
# start store output
# coffea_output/ttbar_ele/merged_144_1080816.root
# start store output
# coffea_output/ttbar_ele/merged_172_582150.root
# start store output
# coffea_output/ttbar_ele/merged_172_970250.root
# start store output
# coffea_output/ttbar_ele/merged_172_485125.root
# start store output
# coffea_output/ttbar_ele/merged_144_982560.root
# start store output
# coffea_output/ttbar_ele/merged_172_776200.root
# start store output
# coffea_output/ttbar_ele/merged_196_897741.root
# start store output
# coffea_output/ttbar_ele/merged_196_299247.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_39_504785.root
# coffea_output/ttbar_ele/merged_196_598494.root
# start store output
# coffea_output/ttbar_ele/merged_172_97025.root
# start store output
# coffea_output/ttbar_ele/merged_190_598530.root
# start store output
# coffea_output/ttbar_ele/merged_144_589536.root
# start store output
# coffea_output/ttbar_ele/merged_39_605742.root
# start store output
# coffea_output/ttbar_ele/merged_39_201914.root
# start store output
# coffea_output/ttbar_ele/merged_196_1097229.root
# start store output
# coffea_output/ttbar_ele/merged_196_398996.root
# start store output
# coffea_output/ttbar_ele/merged_39_706699.root
# start store output
# coffea_output/ttbar_ele/merged_39_1009570.root
# start store output
# coffea_output/ttbar_ele/merged_144_491280.root
# start store output
# coffea_output/ttbar_ele/merged_144_786048.root
# start store output
# coffea_output/ttbar_ele/merged_39_302871.root
# start store output
# coffea_output/ttbar_ele/merged_144_294768.root
# start store output
# coffea_output/ttbar_ele/merged_144_393024.root
# start store output
# coffea_output/ttbar_ele/merged_144_98256.root
# start store output
# coffea_output/ttbar_ele/merged_39_403828.root
# start store output
# coffea_output/ttbar_ele/merged_144_687792.root
# start store output
# coffea_output/ttbar_ele/merged_39_807656.root
# start store output
# coffea_output/ttbar_ele/merged_39_908613.root
# start store output
# coffea_output/ttbar_ele/merged_190_798040.root
# start store output
# coffea_output/ttbar_ele/merged_190_698285.root
# start store output
# coffea_output/ttbar_ele/merged_190_1097298.root
# start store output
# coffea_output/ttbar_ele/merged_190_997550.root
# start store output
# coffea_output/ttbar_ele/merged_190_897795.root
# start store output
# coffea_output/ttbar_ele/merged_195_99672.root
# start store output
# coffea_output/ttbar_ele/merged_195_398688.root
# start store output
# coffea_output/ttbar_ele/merged_195_498360.root
# start store output
# coffea_output/ttbar_ele/merged_195_299016.root
# start store output
# coffea_output/ttbar_ele/merged_195_199344.root
# start store output
# coffea_output/ttbar_ele/merged_29_499510.root
# start store output
# coffea_output/ttbar_ele/merged_29_699314.root
# start store output
# coffea_output/ttbar_ele/merged_29_299706.root
# start store output
# coffea_output/ttbar_ele/merged_29_899118.root
# start store output
# coffea_output/ttbar_ele/merged_29_1098918.root
# start store output
# coffea_output/ttbar_ele/merged_29_999020.root
# start store output
# coffea_output/ttbar_ele/merged_29_599412.root
# start store output
# coffea_output/ttbar_ele/merged_29_99902.root
# start store output
# coffea_output/ttbar_ele/merged_29_199804.root
# start store output
# coffea_output/ttbar_ele/merged_29_399608.root
# start store output
#
# coffea_output/ttbar_ele/merged_29_799216.rootstart store output
# coffea_output/ttbar_ele/merged_13_99936.root
# start store output
# coffea_output/ttbar_ele/merged_13_899424.root
# start store output
# coffea_output/ttbar_ele/merged_13_599616.root
# start store output
# coffea_output/ttbar_ele/merged_13_499680.root
# start store output
# coffea_output/ttbar_ele/merged_13_699552.root
# start store outputstart store output
#
# coffea_output/ttbar_ele/merged_13_999360.rootcoffea_output/ttbar_ele/merged_13_1099295.root
#
# start store output
# coffea_output/ttbar_ele/merged_13_799488.root
# start store output
# coffea_output/ttbar_ele/merged_13_299808.root
# start store output
# coffea_output/ttbar_ele/merged_13_399744.root
# start store output
# coffea_output/ttbar_ele/merged_13_199872.root
# start store output
# coffea_output/ttbar_ele/merged_142_199774.root
# start store output
# coffea_output/ttbar_ele/merged_195_897048.root
# start store output
# coffea_output/ttbar_ele/merged_142_599322.root
# start store output
# coffea_output/ttbar_ele/merged_195_598032.root
# start store output
# coffea_output/ttbar_ele/merged_142_1098756.root
# start store output
# coffea_output/ttbar_ele/merged_195_1096389.root
# start store output
# coffea_output/ttbar_ele/merged_195_797376.root
# start store output
# coffea_output/ttbar_ele/merged_142_699209.root
# start store output
# coffea_output/ttbar_ele/merged_195_996720.root
# start store output
# coffea_output/ttbar_ele/merged_195_697704.root
# start store output
# coffea_output/ttbar_ele/merged_142_998870.root
# start store output
# coffea_output/ttbar_ele/merged_142_299661.root
# start store output
# coffea_output/ttbar_ele/merged_142_399548.root
# start store output
# coffea_output/ttbar_ele/merged_142_898983.root
# start store output
# coffea_output/ttbar_ele/merged_142_99887.root
# start store output
# coffea_output/ttbar_ele/merged_142_499435.root
# start store output
# coffea_output/ttbar_ele/merged_142_799096.root
# start store output
# coffea_output/ttbar_ele/merged_31_600264.root
# start store output
# coffea_output/ttbar_ele/merged_31_300132.root
# start store output
# coffea_output/ttbar_ele/merged_19_499125.root
# start store output
# coffea_output/ttbar_ele/merged_31_1000440.root
# start store output
# coffea_output/ttbar_ele/merged_31_400176.root
# start store output
# coffea_output/ttbar_ele/merged_19_399300.root
# start store output
# coffea_output/ttbar_ele/merged_31_1100478.root
# start store output
# coffea_output/ttbar_ele/merged_19_698775.root
# start store output
# coffea_output/ttbar_ele/merged_31_200088.root
# start store output
# coffea_output/ttbar_ele/merged_19_1098066.root
# start store output
# coffea_output/ttbar_ele/merged_31_700308.root
# start store output
# coffea_output/ttbar_ele/merged_19_998250.root
# start store output
# coffea_output/ttbar_ele/merged_31_800352.root
# start store output
# coffea_output/ttbar_ele/merged_31_100044.root
# start store output
# coffea_output/ttbar_ele/merged_31_500220.root
# start store output
# coffea_output/ttbar_ele/merged_31_900396.root
# start store output
# coffea_output/ttbar_ele/merged_19_99825.root
# start store output
# coffea_output/ttbar_ele/merged_19_598950.root
# start store output
# coffea_output/ttbar_ele/merged_19_798600.root
# start store output
# coffea_output/ttbar_ele/merged_19_299475.root
# start store output
# coffea_output/ttbar_ele/merged_19_898425.root
# start store output
# coffea_output/ttbar_ele/merged_19_199650.root
# start store output
# coffea_output/ttbar_ele/merged_121_674492.root
# start store output
# coffea_output/ttbar_ele/merged_121_96356.root
# start store output
# coffea_output/ttbar_ele/merged_121_1059908.root
# start store output
# coffea_output/ttbar_ele/merged_121_770848.root
# start store output
# coffea_output/ttbar_ele/merged_121_289068.root
# start store output
# coffea_output/ttbar_ele/merged_121_192712.root
# start store output
# coffea_output/ttbar_ele/merged_121_867204.root
# start store output
# coffea_output/ttbar_ele/merged_121_578136.root
# start store output
# coffea_output/ttbar_ele/merged_121_385424.root
# start store output
# coffea_output/ttbar_ele/merged_121_481780.root
# start store output
# coffea_output/ttbar_ele/merged_121_963560.root
# start store output
# coffea_output/ttbar_ele/merged_200_202966.root
# start store output
# coffea_output/ttbar_ele/merged_200_913347.root
# start store output
# coffea_output/ttbar_ele/merged_200_101483.root
# start store output
# coffea_output/ttbar_ele/merged_200_507415.root
# start store output
# coffea_output/ttbar_ele/merged_22_100050.root
# start store output
# coffea_output/ttbar_ele/merged_200_811864.root
# start store output
# coffea_output/ttbar_ele/merged_200_710381.root
# start store output
# coffea_output/ttbar_ele/merged_200_1014821.root
# start store output
# coffea_output/ttbar_ele/merged_200_608898.root
# start store output
# coffea_output/ttbar_ele/merged_200_405932.root
# start store output
# coffea_output/ttbar_ele/merged_200_304449.root
# start store output
# coffea_output/ttbar_ele/merged_22_700350.root
# start store output
# coffea_output/ttbar_ele/merged_22_1100543.root
# start store output
# coffea_output/ttbar_ele/merged_22_300150.root
# start store output
# coffea_output/ttbar_ele/merged_22_600300.root
# start store output
# coffea_output/ttbar_ele/merged_22_900450.root
# start store output
# coffea_output/ttbar_ele/merged_22_800400.root
# start store output
# coffea_output/ttbar_ele/merged_22_500250.root
# start store output
# coffea_output/ttbar_ele/merged_22_1000500.root
# start store output
# coffea_output/ttbar_ele/merged_22_200100.root
# start store output
# coffea_output/ttbar_ele/merged_22_400200.root
# start store output
# coffea_output/ttbar_ele/merged_69_299220.root
# start store output
# coffea_output/ttbar_ele/merged_69_598440.root
# start store output
# coffea_output/ttbar_ele/merged_134_200000.root
# start store output
# coffea_output/ttbar_ele/merged_69_797920.root
# start store output
# coffea_output/ttbar_ele/merged_69_398960.root
# start store output
# coffea_output/ttbar_ele/merged_69_498700.root
# start store output
# coffea_output/ttbar_ele/merged_69_698180.root
# start store output
# coffea_output/ttbar_ele/merged_69_1097132.root
# start store output
# coffea_output/ttbar_ele/merged_69_897660.root
# start store output
# coffea_output/ttbar_ele/merged_69_997400.root
# start store output
# coffea_output/ttbar_ele/merged_69_99740.root
# start store output
# coffea_output/ttbar_ele/merged_148_299706.root
# start store output
# coffea_output/ttbar_ele/merged_69_199480.root
# start store output
# coffea_output/ttbar_ele/merged_134_100000.root
# start store output
# coffea_output/ttbar_ele/merged_148_999020.root
# start store output
# coffea_output/ttbar_ele/merged_134_700000.root
# start store output
# coffea_output/ttbar_ele/merged_134_500000.root
# start store output
# coffea_output/ttbar_ele/merged_165_97272.root
# start store output
# coffea_output/ttbar_ele/merged_165_486360.root
# start store output
# coffea_output/ttbar_ele/merged_134_600000.root
# start store output
# coffea_output/ttbar_ele/merged_134_1000000.root
# start store output
# coffea_output/ttbar_ele/merged_134_800000.root
# start store output
# coffea_output/ttbar_ele/merged_134_400000.root
# start store output
# coffea_output/ttbar_ele/merged_165_291816.root
# start store output
# coffea_output/ttbar_ele/merged_165_194544.root
# start store output
# coffea_output/ttbar_ele/merged_148_199804.root
# start store output
# coffea_output/ttbar_ele/merged_148_699314.root
# start store output
# coffea_output/ttbar_ele/merged_165_389088.root
# start store output
# coffea_output/ttbar_ele/merged_148_99902.root
# start store output
# coffea_output/ttbar_ele/merged_134_1099993.root
# start store output
# coffea_output/ttbar_ele/merged_148_499510.root
# start store output
# coffea_output/ttbar_ele/merged_134_900000.root
# start store output
# coffea_output/ttbar_ele/merged_134_300000.root
# start store output
# coffea_output/ttbar_ele/merged_148_799216.root
# start store output
# coffea_output/ttbar_ele/merged_148_599412.root
# start store output
# coffea_output/ttbar_ele/merged_148_399608.root
# start store output
# coffea_output/ttbar_ele/merged_148_899118.root
# start store output
# coffea_output/ttbar_ele/merged_165_972720.root
# start store output
# coffea_output/ttbar_ele/merged_148_1098914.root
# start store output
# coffea_output/ttbar_ele/merged_165_583632.root
# start store output
# coffea_output/ttbar_ele/merged_165_875448.root
# start store output
# coffea_output/ttbar_ele/merged_165_1069991.root
# start store output
# coffea_output/ttbar_ele/merged_165_778176.root
# start store output
# coffea_output/ttbar_ele/merged_165_680904.root
# start store output
# coffea_output/ttbar_ele/merged_45_199764.root
# start store output
# coffea_output/ttbar_ele/merged_45_1098699.root
# start store output
# coffea_output/ttbar_ele/merged_45_499410.root
# start store output
# coffea_output/ttbar_ele/merged_45_699174.root
# start store output
# coffea_output/ttbar_ele/merged_45_299646.root
# start store output
# coffea_output/ttbar_ele/merged_45_99882.root
# start store output
# coffea_output/ttbar_ele/merged_45_599292.root
# start store output
# coffea_output/ttbar_ele/merged_45_998820.root
# start store output
# coffea_output/ttbar_ele/merged_45_399528.root
# start store output
# coffea_output/ttbar_ele/merged_45_799056.root
# start store output
# coffea_output/ttbar_ele/merged_45_898938.root
# start store output
# coffea_output/ttbar_ele/merged_169_499230.root
# start store output
# coffea_output/ttbar_ele/merged_169_399384.root
# start store output
# coffea_output/ttbar_ele/merged_169_798768.root
# start store output
# coffea_output/ttbar_ele/merged_169_1098304.root
# start store output
# coffea_output/ttbar_ele/merged_169_898614.root
# start store output
# coffea_output/ttbar_ele/merged_169_199692.root
# start store output
# coffea_output/ttbar_ele/merged_169_998460.root
# start store output
# coffea_output/ttbar_ele/merged_169_299538.root
# start store output
# coffea_output/ttbar_ele/merged_169_698922.root
# start store output
# coffea_output/ttbar_ele/merged_169_99846.root
# start store output
# coffea_output/ttbar_ele/merged_169_599076.root
# start store output
# coffea_output/ttbar_ele/merged_205_96984.root
# start store output
# coffea_output/ttbar_ele/merged_212_399876.root
# start store output
# coffea_output/ttbar_ele/merged_205_484920.root
# start store output
# coffea_output/ttbar_ele/merged_205_193968.root
# start store output
# coffea_output/ttbar_ele/merged_212_899721.root
# start store output
# coffea_output/ttbar_ele/merged_212_199938.root
# start store output
# coffea_output/ttbar_ele/merged_205_387936.root
# start store output
# coffea_output/ttbar_ele/merged_212_99969.root
# start store output
# coffea_output/ttbar_ele/merged_205_290952.root
# start store output
# coffea_output/ttbar_ele/merged_212_799752.root
# start store output
# coffea_output/ttbar_ele/merged_212_999690.root
# start store output
# coffea_output/ttbar_ele/merged_212_1099659.root
# start store output
# coffea_output/ttbar_ele/merged_212_599814.root
# start store output
# coffea_output/ttbar_ele/merged_212_299907.root
# start store output
# coffea_output/ttbar_ele/merged_205_872856.root
# start store output
# coffea_output/ttbar_ele/merged_212_699783.root
# start store output
# coffea_output/ttbar_ele/merged_212_499845.root
# start store output
# coffea_output/ttbar_ele/merged_23_785120.root
# start store output
# coffea_output/ttbar_ele/merged_205_775872.root
# start store output
# coffea_output/ttbar_ele/merged_161_297375.root
# start store output
# coffea_output/ttbar_ele/merged_23_588840.root
# start store output
# coffea_output/ttbar_ele/merged_161_495625.root
# start store output
# coffea_output/ttbar_ele/merged_161_892125.root
# start store output
# coffea_output/ttbar_ele/merged_205_678888.root
# start store output
# coffea_output/ttbar_ele/merged_205_969840.root
# start store output
# coffea_output/ttbar_ele/merged_23_294420.root
# start store output
# coffea_output/ttbar_ele/merged_161_594750.root
# start store output
# coffea_output/ttbar_ele/merged_205_1066818.root
# start store output
# coffea_output/ttbar_ele/merged_161_396500.root
# start store output
# coffea_output/ttbar_ele/merged_205_581904.root
# start store output
# coffea_output/ttbar_ele/merged_161_693875.root
# start store output
# coffea_output/ttbar_ele/merged_23_392560.root
# start store output
# coffea_output/ttbar_ele/merged_161_99125.root
# start store output
# coffea_output/ttbar_ele/merged_23_981400.root
# start store output
# coffea_output/ttbar_ele/merged_161_991250.root
# start store output
# coffea_output/ttbar_ele/merged_23_196280.root
# start store output
# coffea_output/ttbar_ele/merged_161_1090366.root
# start store output
# coffea_output/ttbar_ele/merged_161_793000.root
# start store output
# coffea_output/ttbar_ele/merged_161_198250.root
# start store output
# coffea_output/ttbar_ele/merged_23_98140.root
# start store output
# coffea_output/ttbar_ele/merged_23_1079530.root
# start store output
# coffea_output/ttbar_ele/merged_23_883260.root
# start store output
# coffea_output/ttbar_ele/merged_23_490700.root
# start store output
# coffea_output/ttbar_ele/merged_23_686980.root
# start store output
# coffea_output/ttbar_ele/merged_57_99730.root
# start store output
# coffea_output/ttbar_ele/merged_57_199460.root
# start store output
# coffea_output/ttbar_ele/merged_57_897570.root
# start store output
# coffea_output/ttbar_ele/merged_57_498650.root
# start store output
# coffea_output/ttbar_ele/merged_57_698110.root
# start store output
# coffea_output/ttbar_ele/merged_57_1097020.root
# start store output
# coffea_output/ttbar_ele/merged_57_997300.root
# start store output
# coffea_output/ttbar_ele/merged_57_797840.root
# start store output
# coffea_output/ttbar_ele/merged_57_398920.root
# start store output
# coffea_output/ttbar_ele/merged_57_299190.root
# start store output
# coffea_output/ttbar_ele/merged_57_598380.root
# start store output
# coffea_output/ttbar_ele/merged_168_199728.root
# start store output
# coffea_output/ttbar_ele/merged_168_499320.root
# start store output
# coffea_output/ttbar_ele/merged_168_299592.root
# start store output
# coffea_output/ttbar_ele/merged_168_599184.root
# start store output
# coffea_output/ttbar_ele/merged_168_1098500.root
# start store output
# coffea_output/ttbar_ele/merged_168_99864.root
# start store output
# coffea_output/ttbar_ele/merged_168_699048.root
# start store output
# coffea_output/ttbar_ele/merged_168_998640.root
# start store output
# coffea_output/ttbar_ele/merged_168_898776.root
# start store output
# coffea_output/ttbar_ele/merged_168_399456.root
# start store output
# coffea_output/ttbar_ele/merged_168_798912.root
# start store output
# coffea_output/ttbar_ele/merged_71_1097152.root
# start store output
# coffea_output/ttbar_ele/merged_74_498525.root
# start store output
# coffea_output/ttbar_ele/merged_71_199484.root
# start store output
# coffea_output/ttbar_ele/merged_74_99705.root
# start store output
# coffea_output/ttbar_ele/merged_71_299226.root
# start store output
# coffea_output/ttbar_ele/merged_74_199410.root
# start store output
# coffea_output/ttbar_ele/merged_71_997420.root
# start store output
# coffea_output/ttbar_ele/merged_74_1096749.root
# start store output
# coffea_output/ttbar_ele/merged_71_99742.root
# start store output
# coffea_output/ttbar_ele/merged_71_498710.root
# start store output
# coffea_output/ttbar_ele/merged_74_398820.root
# start store output
# coffea_output/ttbar_ele/merged_74_797640.root
# start store output
# coffea_output/ttbar_ele/merged_74_299115.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_71_698194.root
# coffea_output/ttbar_ele/merged_74_897345.root
# start store output
# coffea_output/ttbar_ele/merged_74_598230.root
# start store output
# coffea_output/ttbar_ele/merged_71_598452.root
# start store output
# coffea_output/ttbar_ele/merged_71_897678.root
# start store output
# coffea_output/ttbar_ele/merged_71_797936.root
# start store output
# coffea_output/ttbar_ele/merged_74_697935.root
# start store output
# coffea_output/ttbar_ele/merged_74_997050.root
# start store output
# coffea_output/ttbar_ele/merged_71_398968.root
# start store output
# coffea_output/ttbar_ele/merged_48_599526.root
# start store output
# coffea_output/ttbar_ele/merged_48_899289.root
# start store output
# coffea_output/ttbar_ele/merged_48_999210.root
# start store output
# coffea_output/ttbar_ele/merged_48_499605.root
# start store output
# coffea_output/ttbar_ele/merged_48_699447.root
# start store output
# coffea_output/ttbar_ele/merged_48_199842.root
# start store output
# coffea_output/ttbar_ele/merged_48_399684.root
# start store output
# coffea_output/ttbar_ele/merged_48_1099129.root
# start store output
# coffea_output/ttbar_ele/merged_48_99921.root
# start store output
# coffea_output/ttbar_ele/merged_48_799368.root
# start store output
# coffea_output/ttbar_ele/merged_48_299763.root
# start store output
# coffea_output/ttbar_ele/merged_24_299649.root
# start store output
# coffea_output/ttbar_ele/merged_24_898947.root
# start store output
# coffea_output/ttbar_ele/merged_24_998830.root
# start store output
# coffea_output/ttbar_ele/merged_24_1098712.root
# start store output
# coffea_output/ttbar_ele/merged_24_199766.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_24_499415.root
# coffea_output/ttbar_ele/merged_24_599298.root
# start store output
# coffea_output/ttbar_ele/merged_24_699181.root
# start store output
# coffea_output/ttbar_ele/merged_24_99883.root
# start store output
# coffea_output/ttbar_ele/merged_24_799064.root
# start store output
# coffea_output/ttbar_ele/merged_24_399532.root
# start store output
# coffea_output/ttbar_ele/merged_21_99651.root
# start store output
# coffea_output/ttbar_ele/merged_21_398604.root
# start store output
# coffea_output/ttbar_ele/merged_37_99779.root
# start store output
# coffea_output/ttbar_ele/merged_21_199302.root
# start store output
# coffea_output/ttbar_ele/merged_21_1096160.root
# start store output
# coffea_output/ttbar_ele/merged_21_996510.root
# start store output
# coffea_output/ttbar_ele/merged_21_498255.root
# start store output
# coffea_output/ttbar_ele/merged_21_697557.root
# start store output
# coffea_output/ttbar_ele/merged_21_298953.root
# start store output
# coffea_output/ttbar_ele/merged_21_797208.root
# start store output
# coffea_output/ttbar_ele/merged_21_597906.root
# start store output
# coffea_output/ttbar_ele/merged_21_896859.root
# start store output
# coffea_output/ttbar_ele/merged_37_199558.root
# start store output
# coffea_output/ttbar_ele/merged_37_399116.root
# start store output
# coffea_output/ttbar_ele/merged_37_299337.root
# start store output
# coffea_output/ttbar_ele/merged_37_498895.root
# start store output
# coffea_output/ttbar_ele/merged_37_997790.root
# start store output
# coffea_output/ttbar_ele/merged_37_798232.root
# start store output
# coffea_output/ttbar_ele/merged_37_698453.root
# start store output
# coffea_output/ttbar_ele/merged_37_598674.root
# start store output
# coffea_output/ttbar_ele/merged_37_1097568.root
# start store output
# coffea_output/ttbar_ele/merged_37_898011.root
# start store output
# ...
# coffea_output/ttbar_ele/merged_149_997380.root
# start store output
# coffea_output/ttbar_ele/merged_149_99738.root
# start store output
# coffea_output/ttbar_ele/merged_101_399848.root
# start store output
# coffea_output/ttbar_ele/merged_101_99962.root
# start store output
# coffea_output/ttbar_ele/merged_101_499810.root
# start store output
# coffea_output/ttbar_ele/merged_101_799696.root
# start store output
# coffea_output/ttbar_ele/merged_101_699734.root
# start store output
# coffea_output/ttbar_ele/merged_101_999620.root
# start store output
# coffea_output/ttbar_ele/merged_101_599772.root
# start store output
# coffea_output/ttbar_ele/merged_101_199924.root
# start store output
# coffea_output/ttbar_ele/merged_101_899658.root
# start store output
# coffea_output/ttbar_ele/merged_101_1099573.root
# start store output
# coffea_output/ttbar_ele/merged_101_299886.root
# start store output
# coffea_output/ttbar_ele/merged_131_897696.root
# start store output
# coffea_output/ttbar_ele/merged_131_398976.root
# start store output
# coffea_output/ttbar_ele/merged_131_598464.root
# start store output
# coffea_output/ttbar_ele/merged_131_698208.root
# start store output
# coffea_output/ttbar_ele/merged_131_498720.root
# start store output
# coffea_output/ttbar_ele/merged_131_99744.root
# start store output
# coffea_output/ttbar_ele/merged_131_299232.root
# start store output
# coffea_output/ttbar_ele/merged_131_797952.root
# start store output
# coffea_output/ttbar_ele/merged_131_199488.root
# start store output
# coffea_output/ttbar_ele/merged_131_997440.root
# start store output
# coffea_output/ttbar_ele/merged_131_1097176.root
# start store output
# coffea_output/ttbar_ele/merged_55_294831.root
# start store output
# coffea_output/ttbar_ele/merged_55_196554.root
# start store output
# coffea_output/ttbar_ele/merged_55_393108.root
# start store output
# coffea_output/ttbar_ele/merged_55_589662.root
# start store output
# coffea_output/ttbar_ele/merged_55_884493.root
# start store output
# coffea_output/ttbar_ele/merged_55_98277.root
# start store output
# coffea_output/ttbar_ele/merged_55_1081043.root
# start store output
# coffea_output/ttbar_ele/merged_55_982770.root
# start store output
# coffea_output/ttbar_ele/merged_55_491385.root
# start store output
# coffea_output/ttbar_ele/merged_55_786216.root
# start store output
# coffea_output/ttbar_ele/merged_55_687939.root
# start store output
# coffea_output/ttbar_ele/merged_192_498935.root
# start store output
# coffea_output/ttbar_ele/merged_192_598722.root
# start store output
# coffea_output/ttbar_ele/merged_192_898083.root
# start store output
# coffea_output/ttbar_ele/merged_192_299361.root
# start store output
# coffea_output/ttbar_ele/merged_12_899325.root
# start store output
# coffea_output/ttbar_ele/merged_192_199574.root
# start store output
# coffea_output/ttbar_ele/merged_12_599550.root
# start store output
# coffea_output/ttbar_ele/merged_192_798296.root
# start store output
# coffea_output/ttbar_ele/merged_192_1097648.root
# start store output
# coffea_output/ttbar_ele/merged_192_698509.root
# start store output
# coffea_output/ttbar_ele/merged_192_399148.root
# start store output
# coffea_output/ttbar_ele/merged_192_997870.root
# start store output
# coffea_output/ttbar_ele/merged_192_99787.root
# start store output
# coffea_output/ttbar_ele/merged_12_999250.root
# start store output
# coffea_output/ttbar_ele/merged_12_499625.root
# start store output
# coffea_output/ttbar_ele/merged_12_1099168.root
# start store output
# coffea_output/ttbar_ele/merged_12_299775.root
# start store output
# coffea_output/ttbar_ele/merged_12_799400.root
# start store output
# coffea_output/ttbar_ele/merged_12_399700.root
# start store output
# coffea_output/ttbar_ele/merged_12_99925.root
# start store output
# coffea_output/ttbar_ele/merged_12_699475.root
# start store output
# coffea_output/ttbar_ele/merged_12_199850.root
# start store output
# coffea_output/ttbar_ele/merged_173_99905.root
# start store output
# coffea_output/ttbar_ele/merged_173_299715.root
# start store output
# coffea_output/ttbar_ele/merged_173_499525.root
# start store output
# coffea_output/ttbar_ele/merged_173_599430.root
# start store output
# coffea_output/ttbar_ele/merged_173_1098950.root
# start store output
# coffea_output/ttbar_ele/merged_173_399620.root
# start store output
# coffea_output/ttbar_ele/merged_173_799240.root
# start store output
# coffea_output/ttbar_ele/merged_173_199810.root
# start store output
# coffea_output/ttbar_ele/merged_173_899145.root
# start store output
# coffea_output/ttbar_ele/merged_173_699335.root
# start store output
# coffea_output/ttbar_ele/merged_173_999050.root
# start store output
# coffea_output/ttbar_ele/merged_110_199524.root
# start store output
# coffea_output/ttbar_ele/merged_110_498810.root
# start store output
# coffea_output/ttbar_ele/merged_110_997620.root
# start store output
# coffea_output/ttbar_ele/merged_110_299286.root
# start store output
# coffea_output/ttbar_ele/merged_110_798096.root
# start store output
# coffea_output/ttbar_ele/merged_110_698334.root
# start store output
# coffea_output/ttbar_ele/merged_110_598572.root
# start store output
# coffea_output/ttbar_ele/merged_110_897858.root
# start store output
# coffea_output/ttbar_ele/merged_110_99762.root
# start store output
# coffea_output/ttbar_ele/merged_110_1097377.root
# start store output
# coffea_output/ttbar_ele/merged_110_399048.root
# start store output
# coffea_output/ttbar_ele/merged_140_299319.root
# start store output
# coffea_output/ttbar_ele/merged_140_199546.root
# start store output
# coffea_output/ttbar_ele/merged_140_498865.root
# start store output
# coffea_output/ttbar_ele/merged_140_399092.root
# start store output
# coffea_output/ttbar_ele/merged_140_99773.root
# start store output
# coffea_output/ttbar_ele/merged_140_598638.root
# start store output
# coffea_output/ttbar_ele/merged_140_698411.root
# start store output
# coffea_output/ttbar_ele/merged_140_1097494.root
# start store output
# coffea_output/ttbar_ele/merged_140_897957.root
# start store output
# coffea_output/ttbar_ele/merged_140_997730.root
# start store output
# coffea_output/ttbar_ele/merged_140_798184.root
# start store output
# coffea_output/ttbar_ele/merged_128_399520.root
# start store output
# coffea_output/ttbar_ele/merged_128_699160.root
# start store output
# coffea_output/ttbar_ele/merged_128_1098678.root
# start store output
# coffea_output/ttbar_ele/merged_128_99880.root
# start store output
# coffea_output/ttbar_ele/merged_128_599280.root
# start store output
# coffea_output/ttbar_ele/merged_128_799040.root
# start store output
# coffea_output/ttbar_ele/merged_128_998800.root
# start store output
# coffea_output/ttbar_ele/merged_128_199760.root
# start store output
# coffea_output/ttbar_ele/merged_128_299640.root
# start store output
# coffea_output/ttbar_ele/merged_128_898920.root
# start store output
# coffea_output/ttbar_ele/merged_128_499400.root
# start store output
# coffea_output/ttbar_ele/merged_223_386500.root
# start store output
# coffea_output/ttbar_ele/merged_223_579750.root
# start store output
# coffea_output/ttbar_ele/merged_223_676373.root
# start store output
# coffea_output/ttbar_ele/merged_223_96625.root
# start store output
# coffea_output/ttbar_ele/merged_223_193250.root
# start store output
# coffea_output/ttbar_ele/merged_223_483125.root
# start store output
# coffea_output/ttbar_ele/merged_223_289875.root
# start store output
# coffea_output/ttbar_ele/merged_100_200014.root
# start store output
# coffea_output/ttbar_ele/merged_100_1000070.root
# start store output
# coffea_output/ttbar_ele/merged_8_699076.root
# start store output
# coffea_output/ttbar_ele/merged_100_300021.root
# start store output
# coffea_output/ttbar_ele/merged_8_399472.root
# start store output
# coffea_output/ttbar_ele/merged_100_900063.root
# start store output
# coffea_output/ttbar_ele/merged_100_600042.root
# start store output
# coffea_output/ttbar_ele/merged_100_400028.root
# start store output
# coffea_output/ttbar_ele/merged_8_99868.root
# start store output
# coffea_output/ttbar_ele/merged_8_798944.root
# start store output
# coffea_output/ttbar_ele/merged_8_898812.root
# start store output
# coffea_output/ttbar_ele/merged_8_499340.root
# start store output
# coffea_output/ttbar_ele/merged_100_1100069.root
# start store output
# coffea_output/ttbar_ele/merged_100_800056.root
# start store output
# coffea_output/ttbar_ele/merged_8_299604.root
# start store output
# coffea_output/ttbar_ele/merged_8_199736.root
# start store output
# coffea_output/ttbar_ele/merged_100_100007.root
# start store output
# coffea_output/ttbar_ele/merged_100_500035.root
# start store output
# coffea_output/ttbar_ele/merged_100_700049.root
# start store output
# coffea_output/ttbar_ele/merged_8_1098544.root
# start store output
# coffea_output/ttbar_ele/merged_8_599208.root
# start store output
# coffea_output/ttbar_ele/merged_8_998680.root
# start store output
# coffea_output/ttbar_ele/merged_112_289716.root
# start store output
# coffea_output/ttbar_ele/merged_112_386288.root
# start store output
# coffea_output/ttbar_ele/merged_112_579432.root
# start store output
# coffea_output/ttbar_ele/merged_112_965720.root
# start store output
# coffea_output/ttbar_ele/merged_112_869148.root
# start store output
# coffea_output/ttbar_ele/merged_112_482860.root
# start store output
# coffea_output/ttbar_ele/merged_112_96572.root
# start store output
# coffea_output/ttbar_ele/merged_112_676004.root
# start store output
# coffea_output/ttbar_ele/merged_112_1062290.root
# start store output
# coffea_output/ttbar_ele/merged_112_772576.root
# start store output
# coffea_output/ttbar_ele/merged_112_193144.root
# start store output
# coffea_output/ttbar_ele/merged_33_799264.root
# start store output
# coffea_output/ttbar_ele/merged_33_99908.root
# start store output
# coffea_output/ttbar_ele/merged_33_599448.root
# start store output
# coffea_output/ttbar_ele/merged_33_199816.root
# start store output
# coffea_output/ttbar_ele/merged_33_299724.root
# start store output
# coffea_output/ttbar_ele/merged_33_499540.root
# start store output
# coffea_output/ttbar_ele/merged_33_1098984.root
# start store output
# coffea_output/ttbar_ele/merged_33_399632.root
# start store output
# coffea_output/ttbar_ele/merged_33_899172.root
# start store output
# coffea_output/ttbar_ele/merged_33_999080.root
# start store output
# coffea_output/ttbar_ele/merged_33_699356.root
# start store output
# coffea_output/ttbar_ele/merged_78_1097220.root
# start store output
# coffea_output/ttbar_ele/merged_78_598488.root
# start store output
# coffea_output/ttbar_ele/merged_78_398992.root
# start store output
# coffea_output/ttbar_ele/merged_78_299244.root
# start store output
# coffea_output/ttbar_ele/merged_78_199496.root
# start store output
# coffea_output/ttbar_ele/merged_78_99748.root
# start store output
# coffea_output/ttbar_ele/merged_78_698236.root
# start store output
# coffea_output/ttbar_ele/merged_78_498740.root
# start store output
# coffea_output/ttbar_ele/merged_78_797984.root
# start store output
# coffea_output/ttbar_ele/merged_78_897732.root
# start store output
# coffea_output/ttbar_ele/merged_78_997480.root
# start store output
# coffea_output/ttbar_ele/merged_20_898722.root
# start store output
# coffea_output/ttbar_ele/merged_20_998580.root
# start store output
# coffea_output/ttbar_ele/merged_20_199716.root
# start store output
# coffea_output/ttbar_ele/merged_20_1098430.root
# start store output
# coffea_output/ttbar_ele/merged_20_798864.root
# start store output
# coffea_output/ttbar_ele/merged_20_99858.root
# start store output
# coffea_output/ttbar_ele/merged_20_699006.root
# start store output
# coffea_output/ttbar_ele/merged_20_299574.root
# start store output
# coffea_output/ttbar_ele/merged_20_499290.root
# start store output
# coffea_output/ttbar_ele/merged_20_599148.root
# start store output
# coffea_output/ttbar_ele/merged_20_399432.root
# start store output
# coffea_output/ttbar_ele/merged_178_900729.root
# start store output
# coffea_output/ttbar_ele/merged_180_898497.root
# start store output
# coffea_output/ttbar_ele/merged_178_1000810.root
# start store output
# coffea_output/ttbar_ele/merged_180_199666.root
# start store output
# coffea_output/ttbar_ele/merged_178_700567.root
# start store output
# coffea_output/ttbar_ele/merged_180_598998.root
# start store output
# coffea_output/ttbar_ele/merged_178_300243.root
# start store output
# coffea_output/ttbar_ele/merged_180_1098156.root
# start store output
# coffea_output/ttbar_ele/merged_180_698831.root
# start store output
# coffea_output/ttbar_ele/merged_180_798664.root
# start store output
# coffea_output/ttbar_ele/merged_178_1100882.root
# start store output
# coffea_output/ttbar_ele/merged_178_200162.root
# start store output
# start store output
# coffea_output/ttbar_ele/merged_180_499165.root
# coffea_output/ttbar_ele/merged_178_800648.root
# start store output
# coffea_output/ttbar_ele/merged_178_600486.root
# start store output
# coffea_output/ttbar_ele/merged_180_998330.root
# start store output
# coffea_output/ttbar_ele/merged_178_400324.root
# start store output
# coffea_output/ttbar_ele/merged_178_100081.root
# start store output
# coffea_output/ttbar_ele/merged_178_500405.root
# start store output
# coffea_output/ttbar_ele/merged_180_399332.root
# start store output
# coffea_output/ttbar_ele/merged_180_299499.root
# start store output
# coffea_output/ttbar_ele/merged_180_99833.root
# start store output
# coffea_output/ttbar_ele/merged_1_200078.root
# start store output
# coffea_output/ttbar_ele/merged_185_599940.root
# start store output
# coffea_output/ttbar_ele/merged_185_299970.root
# start store output
# coffea_output/ttbar_ele/merged_185_1099881.root
# start store output
# coffea_output/ttbar_ele/merged_1_400156.root
# start store output
# coffea_output/ttbar_ele/merged_185_499950.root
# start store output
# coffea_output/ttbar_ele/merged_185_699930.root
# start store output
# coffea_output/ttbar_ele/merged_1_300117.root
# start store output
# coffea_output/ttbar_ele/merged_185_199980.root
# start store output
# coffea_output/ttbar_ele/merged_185_99990.root
# start store output
# coffea_output/ttbar_ele/merged_185_999900.root
# start store output
# coffea_output/ttbar_ele/merged_1_100039.root
# start store output
# coffea_output/ttbar_ele/merged_185_799920.root
# start store output
# coffea_output/ttbar_ele/merged_185_899910.root
# start store output
# coffea_output/ttbar_ele/merged_185_399960.root
# start store output
# coffea_output/ttbar_ele/merged_1_500195.root
# start store output
# coffea_output/ttbar_ele/merged_1_1100419.root
# start store output
# coffea_output/ttbar_ele/merged_1_800312.root
# start store output
# coffea_output/ttbar_ele/merged_1_700273.root
# start store output
# coffea_output/ttbar_ele/merged_1_1000390.root
# start store output
# coffea_output/ttbar_ele/merged_1_900351.root
# start store output
# coffea_output/ttbar_ele/merged_1_600234.root
# start store output
# coffea_output/ttbar_ele/merged_120_580908.root
# start store output
# coffea_output/ttbar_ele/merged_120_871362.root
# start store output
# coffea_output/ttbar_ele/merged_120_290454.root
# start store output
# coffea_output/ttbar_ele/merged_120_193636.root
# start store output
# coffea_output/ttbar_ele/merged_120_96818.root
# start store output
# coffea_output/ttbar_ele/merged_120_968180.root
# start store output
# coffea_output/ttbar_ele/merged_120_1064989.root
# start store output
# coffea_output/ttbar_ele/merged_120_677726.root
# start store output
# coffea_output/ttbar_ele/merged_120_484090.root
# start store output
# coffea_output/ttbar_ele/merged_120_774544.root
# start store output
# coffea_output/ttbar_ele/merged_64_698383.root
# start store output
# coffea_output/ttbar_ele/merged_120_387272.root
# start store output
# coffea_output/ttbar_ele/merged_64_598614.root
# start store output
# coffea_output/ttbar_ele/merged_64_99769.root
# start store output
# coffea_output/ttbar_ele/merged_64_498845.root
# start store output
# coffea_output/ttbar_ele/merged_64_399076.root
# start store output
# coffea_output/ttbar_ele/merged_64_1097454.root
# start store output
# coffea_output/ttbar_ele/merged_64_798152.root
# start store output
# coffea_output/ttbar_ele/merged_64_897921.root
# start store output
# coffea_output/ttbar_ele/merged_64_299307.root
# start store output
# coffea_output/ttbar_ele/merged_64_997690.root
# start store output
# coffea_output/ttbar_ele/merged_64_199538.root
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
